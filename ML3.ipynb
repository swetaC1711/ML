# %% [markdown]
# <a href="https://colab.research.google.com/github/swetaC1711/ML/blob/main/ML3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EXPLORATORY DATA ANALYSIS(EDA)- PRE MACHINE LEARNING
#EDA - finds different insights,We conclude multiple facts, we explore our data

# %%
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221116%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221116T121546Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep = '\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape #59 rows and 7 columns
# Out:
# (59, 7)

# %%
df.size #It tells us the total number of elements in the dataframe
# Out:
# 413

# %%
df.info() #It gives us the information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#To check the Null/NaN values officially
df.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
#Slicing
#var[inclusive:exclusive]
#Slice row indexes from index 25 to index 43
df[25:44] #25 is inclusive and 44 is exclusive
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# ...

# %%
#Slice row indexes from 25 to 43 and column indexes 0 an 1
#var.iloc[row slicing,column slicing]
#iloc operator is used to slice both rows and cols together
df.iloc[25:44,0:2]
# Out:
#     fruit_label fruit_name
# 25            3     orange
# 26            3     orange
# 27            3     orange
# 28            3     orange
# 29            3     orange
# 30            3     orange
# 31            3     orange
# 32            3     orange
# 33            3     orange
# 34            3     orange
# 35            3     orange
# 36            3     orange
# 37            3     orange
# 38            3     orange
# 39            3     orange
# 40            3     orange
# 41            3     orange
# 42            3     orange
# 43            4      lemon

# %%
#Let us consider the fruit_name column
#Now I just want the exact count of unique fruit names
df.fruit_name.nunique()
# Out:
# 4

# %%
df['fruit_name'].nunique()
# Out:
# 4

# %%
#I just want the unique fruit names
df.fruit_name.unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fname = df['fruit_name'].unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#Now I want the exact count of each and every fruit
#Apple - 19
#Mandarin -5
#Orange - 19
#lemon - 16
fsize = df.groupby('fruit_name',sort = False).size()
fsize
#Whenever we use groupby , it sorts the output in Alphabetical order
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
#VISUALISATION PART
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color = ['Red','pink','orange','lime'])
# Out:
# <BarContainer object of 4 artists>
